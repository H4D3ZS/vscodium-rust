// %% [markdown]
// # Welcome to VSCodium Rust Notebooks 🦀
//
// This is a **native** notebook renderer running directly in the frontend.
// It supports:
// - Markdown cells
// - Code cells
// - Outputs (stdout, stderr, text/plain)

// %%
println!("Hello from Rust!");
// Out:
// Hello from Rust!

// %%
let x = 40 + 2;
x
// Out:
// 42
